# %%
import os
import shutil
import random
import cv2
import numpy as np

# %%
def create_dir_structure(output_path):
    """
    Creates the required directory structure.
    """
    dirs = [
        os.path.join(output_path, 'images/train'),
        os.path.join(output_path, 'images/val'),
        os.path.join(output_path, 'labels/train'),
        os.path.join(output_path, 'labels/val')
    ]

    for dir_path in dirs:
        os.makedirs(dir_path, exist_ok=True)

# %%
def get_file_pairs(base_image_dir, base_label_dir):
    """
    Gets the pairs of image and label files from provided directories.
    """
    image_files = os.listdir(base_image_dir)
    label_files = os.listdir(base_label_dir)
    image_files = [f for f in image_files if f.lower().endswith(('.png', 'jpg', '.jpeg'))]
    label_files = [f for f in label_files if f.lower().endswith('.txt')]

    image_label_pairs = []
    for img_file in image_files:
        label_file = img_file.rsplit('.', 1)[0] + '.txt'
        if label_file in label_files:
            image_label_pairs.append((img_file, label_file))

    return image_label_pairs

# %%
def split_data_percentage(image_label_pairs, train_ratio=0.8):
    """
    Splits the data into training and validation sets (Percentage)
    """
    random.shuffle(image_label_pairs) 
    split_index = int(len(image_label_pairs) * train_ratio)
    train_pairs = image_label_pairs[:split_index]
    val_pairs = image_label_pairs[split_index:]

    return train_pairs, val_pairs

# %%
def split_data_fix_amount(image_label_pairs, train_count=80):
    """
    Splits the data into training and validation sets (Fix Amount)
    """
    if train_count > len(image_label_pairs):
        train_count = len(image_label_pairs)
    
    random.shuffle(image_label_pairs)
    train_pairs = image_label_pairs[train_count:] 
    val_pairs = image_label_pairs[:train_count]

    return train_pairs, val_pairs

# %%
def copy_files(pairs, base_path, output_path, dataset_type):
    """
    Copies the files to the appropriate directories
    """
    for img_file, lbl_file in pairs:
        shutil.copy(os.path.join(base_path, img_file), os.path.join(output_path, f'images/{dataset_type}', img_file))
        shutil.copy(os.path.join(base_path, lbl_file), os.path.join(output_path, f'labels/{dataset_type}', lbl_file))

# %%
def copy_files_with_preprocessing(pairs, base_image_dir, base_label_dir, output_image_dir, output_label_dir, preprocess_func=None):
    """
    Copies the files to the appropriate directories with optional preprocessing.
    skips missing files and already existing files.
    """
    os.makedirs(output_image_dir, exist_ok=True)
    os.makedirs(output_label_dir, exist_ok=True)

    for img_file, lbl_file in pairs:
        img_path = os.path.join(base_image_dir, img_file)
        label_path = os.path.join(base_label_dir, lbl_file)

        # Skip if the image or label file is missing
        if not os.path.exists(img_path) or not os.path.exists(label_path):
            print(f"Skipping missing file pair: {img_file}, {lbl_file}")
            continue

        output_image_file = os.path.join(output_image_dir, img_file)
        output_label_file = os.path.join(output_label_dir, lbl_file)

        # Skip if the image or label file already exists in the destination
        if os.path.exists(output_image_file) or os.path.exists(output_label_file):
            print(f"Skipping already  existing file pair: {img_file}, {lbl_file}")
            continue

        image = cv2.imread(img_path)

        # Apply preprocessing if specified
        if preprocess_func:
            image = preprocess_func(image)

        # output_image_file = os.path.join(output_image_dir, img_file)
        cv2.imwrite(output_image_file, image)
        shutil.copy(label_path, output_label_file)
        # shutil.copy(os.path.join(base_label_dir, lbl_file), os.path.join(output_label_dir, lbl_file))
        print(f"Copied {img_file} and {lbl_file} with preprocessing to {output_image_dir}")

# %%
def apply_image_sharpening(image):
    """
    Apply sharpening to the input image.
    """
    kernel = np.array([[0, -1, 0],
                       [-1, 5,-1],
                       [0, -1, 0]])
    sharpened_image = cv2.filter2D(image, -1, kernel)
    return sharpened_image

# %%
def apply_gaussian_noise(image, mean=0, var=0.1):
    """
    Apply Gaussian noise to the input image.
    """
    sigma = var ** 0.5
    gauss = np.random.normal(mean, sigma, image.shape).astype(np.float32)
    noisy_image = np.clip(image + gauss * 255, 0, 255).astype(np.uint8)
    return noisy_image

# %%
def prepare_dataset(base_path='raw_dataset', output_path='data', train_ratio=None, train_count=None):
    create_dir_structure(output_path)

    image_label_pairs = get_file_pairs(base_path)
    if train_ratio != None:
        train_pairs, val_pairs = split_data_percentage(image_label_pairs, train_ratio)
    else:
        train_pairs, val_pairs = split_data_fix_amount(image_label_pairs, train_count)

    copy_files(train_pairs, base_path, output_path, 'train')
    copy_files(val_pairs, base_path, output_path, 'val')

# %%
def separate_raw_data_to_preprocessing(base_path='my_data_1'):
    base_image_train_path = os.path.join(base_path, 'images/train')
    base_label_train_path = os.path.join(base_path, 'labels/train')
    base_image_val_path = os.path.join(base_path, 'images/val')
    base_label_val_path = os.path.join(base_path, 'labels/val')

    # sharpened_output_path = 'sharpened_data'
    # noisy_output_path = 'noisy_data'
    sharpened_output_image_path = 'sharpened_data/images'
    sharpened_output_label_path = 'sharpened_data/labels'
    noisy_output_image_path = 'noisy_data/images'
    noisy_output_label_path = 'noisy_data/labels'

    # Create directory structure
    create_dir_structure('sharpened_data')
    create_dir_structure('noisy_data')

    # get file pairs for training and validation
    train_pairs = get_file_pairs(base_image_train_path, base_label_train_path)
    val_pairs = get_file_pairs(base_image_val_path, base_label_val_path)

    # Copy files with image sharpening
    copy_files_with_preprocessing(train_pairs, base_image_train_path, base_label_train_path, os.path.join(sharpened_output_image_path, 'train'), os.path.join(sharpened_output_label_path, 'train'), preprocess_func=apply_image_sharpening)
    copy_files_with_preprocessing(val_pairs, base_image_val_path, base_label_val_path, os.path.join(sharpened_output_image_path, 'val'), os.path.join(sharpened_output_label_path, 'val'), preprocess_func=apply_image_sharpening)

    # Copy files with Gaussian noise
    copy_files_with_preprocessing(train_pairs, base_image_train_path, base_label_train_path, os.path.join(noisy_output_image_path, 'train'), os.path.join(noisy_output_label_path, 'train'), preprocess_func=apply_gaussian_noise)
    copy_files_with_preprocessing(val_pairs, base_image_val_path, base_label_val_path, os.path.join(noisy_output_image_path, 'val'), os.path.join(noisy_output_label_path, 'val'), preprocess_func=apply_gaussian_noise)

# %%
# base_path = 'raw_dataset'
# output_path = 'my_data'
# create_dir_structure(output_path)

# image_label_pairs = get_file_pairs(base_path)
# train_pairs, val_pairs = split_data(image_label_pairs)

# copy_files(train_pairs, base_path, output_path, 'train')
# copy_files(val_pairs, base_path, output_path, 'val')

# prepare_dataset(base_path='raw_dataset_2/', output_path='my_data_1', train_count=100)
separate_raw_data_to_preprocessing(base_path='my_data_1')
# Out:
# Skipping already  existing file pair: frame_101280.jpg, frame_101280.txt
# Skipping already  existing file pair: frame_101460.jpg, frame_101460.txt
# Skipping already  existing file pair: frame_101820.jpg, frame_101820.txt
# Skipping already  existing file pair: frame_101940.jpg, frame_101940.txt
# Skipping already  existing file pair: frame_1020.jpg, frame_1020.txt
# Skipping already  existing file pair: frame_102000.jpg, frame_102000.txt
# Skipping already  existing file pair: frame_102180.jpg, frame_102180.txt
# Skipping already  existing file pair: frame_102240.jpg, frame_102240.txt
# Skipping already  existing file pair: frame_102420.jpg, frame_102420.txt
# Skipping already  existing file pair: frame_102480.jpg, frame_102480.txt
# Skipping already  existing file pair: frame_103440.jpg, frame_103440.txt
# Skipping already  existing file pair: frame_103500.jpg, frame_103500.txt
# Skipping already  existing file pair: frame_103680.jpg, frame_103680.txt
# Skipping already  existing file pair: frame_104880.jpg, frame_104880.txt
# Skipping already  existing file pair: frame_105060.jpg, frame_105060.txt
# Skipping already  existing file pair: frame_105180.jpg, frame_105180.txt
# Skipping already  existing file pair: frame_106320.jpg, frame_106320.txt
# Skipping already  existing file pair: frame_106800.jpg, frame_106800.txt
# Skipping already  existing file pair: frame_106980.jpg, frame_106980.txt
# Skipping already  existing file pair: frame_10740.jpg, frame_10740.txt
# Skipping already  existing file pair: frame_107520.jpg, frame_107520.txt
# Skipping already  existing file pair: frame_107580.jpg, frame_107580.txt
# Skipping already  existing file pair: frame_107640.jpg, frame_107640.txt
# Skipping already  existing file pair: frame_107820.jpg, frame_107820.txt
# Skipping already  existing file pair: frame_107880.jpg, frame_107880.txt
# Skipping already  existing file pair: frame_108360.jpg, frame_108360.txt
# Skipping already  existing file pair: frame_109080.jpg, frame_109080.txt
# Skipping already  existing file pair: frame_109140.jpg, frame_109140.txt
# Skipping already  existing file pair: frame_109260.jpg, frame_109260.txt
# Skipping already  existing file pair: frame_109740.jpg, frame_109740.txt
# Skipping already  existing file pair: frame_10980.jpg, frame_10980.txt
# Skipping already  existing file pair: frame_109800.jpg, frame_109800.txt
# Skipping already  existing file pair: frame_109920.jpg, frame_109920.txt
# Skipping already  existing file pair: frame_109980.jpg, frame_109980.txt
# Skipping already  existing file pair: frame_11100.jpg, frame_11100.txt
# Skipping already  existing file pair: frame_11160.jpg, frame_11160.txt
# Skipping already  existing file pair: frame_111840.jpg, frame_111840.txt
# Skipping already  existing file pair: frame_112080.jpg, frame_112080.txt
# Skipping already  existing file pair: frame_112140.jpg, frame_112140.txt
# Skipping already  existing file pair: frame_112920.jpg, frame_112920.txt
# Skipping already  existing file pair: frame_113220.jpg, frame_113220.txt
# Skipping already  existing file pair: frame_113280.jpg, frame_113280.txt
# Skipping already  existing file pair: frame_113340.jpg, frame_113340.txt
# Skipping already  existing file pair: frame_113400.jpg, frame_113400.txt
# Skipping already  existing file pair: frame_114900.jpg, frame_114900.txt
# Skipping already  existing file pair: frame_114960.jpg, frame_114960.txt
# Skipping already  existing file pair: frame_115080.jpg, frame_115080.txt
# Skipping already  existing file pair: frame_115140.jpg, frame_115140.txt
# Skipping already  existing file pair: frame_115260.jpg, frame_115260.txt
# Skipping already  existing file pair: frame_115320.jpg, frame_115320.txt
# Skipping already  existing file pair: frame_115380.jpg, frame_115380.txt
# Skipping already  existing file pair: frame_115500.jpg, frame_115500.txt
# Skipping already  existing file pair: frame_115560.jpg, frame_115560.txt
# Skipping already  existing file pair: frame_115680.jpg, frame_115680.txt
# Skipping already  existing file pair: frame_115740.jpg, frame_115740.txt
# Skipping already  existing file pair: frame_11580.jpg, frame_11580.txt
# Skipping already  existing file pair: frame_115800.jpg, frame_115800.txt
# Skipping already  existing file pair: frame_115860.jpg, frame_115860.txt
# Skipping already  existing file pair: frame_115980.jpg, frame_115980.txt
# Skipping already  existing file pair: frame_116040.jpg, frame_116040.txt
# Skipping already  existing file pair: frame_11640.jpg, frame_11640.txt
# Skipping already  existing file pair: frame_117000.jpg, frame_117000.txt
# Skipping already  existing file pair: frame_117060.jpg, frame_117060.txt
# Skipping already  existing file pair: frame_117120.jpg, frame_117120.txt
# Skipping already  existing file pair: frame_117180.jpg, frame_117180.txt
# Skipping already  existing file pair: frame_117240.jpg, frame_117240.txt
# Skipping already  existing file pair: frame_11760.jpg, frame_11760.txt
# Skipping already  existing file pair: frame_117600.jpg, frame_117600.txt
# Skipping already  existing file pair: frame_117900.jpg, frame_117900.txt
# Skipping already  existing file pair: frame_117960.jpg, frame_117960.txt
# Skipping already  existing file pair: frame_118020.jpg, frame_118020.txt
# Skipping already  existing file pair: frame_118080.jpg, frame_118080.txt
# Skipping already  existing file pair: frame_118140.jpg, frame_118140.txt
# Skipping already  existing file pair: frame_120.jpg, frame_120.txt
# Skipping already  existing file pair: frame_120000.jpg, frame_120000.txt
# Skipping already  existing file pair: frame_120060.jpg, frame_120060.txt
# Skipping already  existing file pair: frame_120120.jpg, frame_120120.txt
# Skipping already  existing file pair: frame_120180.jpg, frame_120180.txt
# Skipping already  existing file pair: frame_121020.jpg, frame_121020.txt
# Skipping already  existing file pair: frame_121080.jpg, frame_121080.txt
# Skipping already  existing file pair: frame_121140.jpg, frame_121140.txt
# Skipping already  existing file pair: frame_12120.jpg, frame_12120.txt
# Skipping already  existing file pair: frame_121380.jpg, frame_121380.txt
# Skipping already  existing file pair: frame_121440.jpg, frame_121440.txt
# Skipping already  existing file pair: frame_121980.jpg, frame_121980.txt
# Skipping already  existing file pair: frame_122040.jpg, frame_122040.txt
# Skipping already  existing file pair: frame_122220.jpg, frame_122220.txt
# Skipping already  existing file pair: frame_122280.jpg, frame_122280.txt
# Skipping already  existing file pair: frame_122340.jpg, frame_122340.txt
# Skipping already  existing file pair: frame_122460.jpg, frame_122460.txt
# Skipping already  existing file pair: frame_122520.jpg, frame_122520.txt
# Skipping already  existing file pair: frame_122580.jpg, frame_122580.txt
# Skipping already  existing file pair: frame_122640.jpg, frame_122640.txt
# Skipping already  existing file pair: frame_122760.jpg, frame_122760.txt
# Skipping already  existing file pair: frame_122820.jpg, frame_122820.txt
# Skipping already  existing file pair: frame_122940.jpg, frame_122940.txt
# Skipping already  existing file pair: frame_123000.jpg, frame_123000.txt
# Skipping already  existing file pair: frame_123060.jpg, frame_123060.txt
# Skipping already  existing file pair: frame_123120.jpg, frame_123120.txt
# Skipping already  existing file pair: frame_123180.jpg, frame_123180.txt
# Skipping already  existing file pair: frame_123240.jpg, frame_123240.txt
# Skipping already  existing file pair: frame_123300.jpg, frame_123300.txt
# Skipping already  existing file pair: frame_123360.jpg, frame_123360.txt
# Skipping already  existing file pair: frame_123420.jpg, frame_123420.txt
# Skipping already  existing file pair: frame_123480.jpg, frame_123480.txt
# Skipping already  existing file pair: frame_123540.jpg, frame_123540.txt
# Skipping already  existing file pair: frame_12360.jpg, frame_12360.txt
# Skipping already  existing file pair: frame_123600.jpg, frame_123600.txt
# Skipping already  existing file pair: frame_123660.jpg, frame_123660.txt
# Skipping already  existing file pair: frame_12420.jpg, frame_12420.txt
# Skipping already  existing file pair: frame_124740.jpg, frame_124740.txt
# Skipping already  existing file pair: frame_124800.jpg, frame_124800.txt
# Skipping already  existing file pair: frame_124860.jpg, frame_124860.txt
# Skipping already  existing file pair: frame_124920.jpg, frame_124920.txt
# Skipping already  existing file pair: frame_124980.jpg, frame_124980.txt
# Skipping already  existing file pair: frame_125040.jpg, frame_125040.txt
# Skipping already  existing file pair: frame_125100.jpg, frame_125100.txt
# Skipping already  existing file pair: frame_125220.jpg, frame_125220.txt
# Skipping already  existing file pair: frame_125280.jpg, frame_125280.txt
# Skipping already  existing file pair: frame_125400.jpg, frame_125400.txt
# Skipping already  existing file pair: frame_125460.jpg, frame_125460.txt
# Skipping already  existing file pair: frame_125820.jpg, frame_125820.txt
# Skipping already  existing file pair: frame_125880.jpg, frame_125880.txt
# Skipping already  existing file pair: frame_1260.jpg, frame_1260.txt
# Skipping already  existing file pair: frame_12600.jpg, frame_12600.txt
# Skipping already  existing file pair: frame_126420.jpg, frame_126420.txt
# Skipping already  existing file pair: frame_126480.jpg, frame_126480.txt
# Skipping already  existing file pair: frame_12660.jpg, frame_12660.txt
# Skipping already  existing file pair: frame_127080.jpg, frame_127080.txt
# Skipping already  existing file pair: frame_12720.jpg, frame_12720.txt
# Skipping already  existing file pair: frame_127440.jpg, frame_127440.txt
# Skipping already  existing file pair: frame_12780.jpg, frame_12780.txt
# Skipping already  existing file pair: frame_12840.jpg, frame_12840.txt
# Skipping already  existing file pair: frame_128460.jpg, frame_128460.txt
# Skipping already  existing file pair: frame_130200.jpg, frame_130200.txt
# Skipping already  existing file pair: frame_130260.jpg, frame_130260.txt
# Skipping already  existing file pair: frame_130320.jpg, frame_130320.txt
# Skipping already  existing file pair: frame_130380.jpg, frame_130380.txt
# Skipping already  existing file pair: frame_1320.jpg, frame_1320.txt
# Skipping already  existing file pair: frame_13200.jpg, frame_13200.txt
# Skipping already  existing file pair: frame_132060.jpg, frame_132060.txt
# Skipping already  existing file pair: frame_132120.jpg, frame_132120.txt
# Skipping already  existing file pair: frame_132720.jpg, frame_132720.txt
# Skipping already  existing file pair: frame_133980.jpg, frame_133980.txt
# Skipping already  existing file pair: frame_134160.jpg, frame_134160.txt
# Skipping already  existing file pair: frame_134940.jpg, frame_134940.txt
# Skipping already  existing file pair: frame_135600.jpg, frame_135600.txt
# Skipping already  existing file pair: frame_135720.jpg, frame_135720.txt
# Skipping already  existing file pair: frame_135900.jpg, frame_135900.txt
# Skipping already  existing file pair: frame_136620.jpg, frame_136620.txt
# Skipping already  existing file pair: frame_136680.jpg, frame_136680.txt
# Skipping already  existing file pair: frame_136740.jpg, frame_136740.txt
# Skipping already  existing file pair: frame_13680.jpg, frame_13680.txt
# Skipping already  existing file pair: frame_137220.jpg, frame_137220.txt
# Skipping already  existing file pair: frame_138240.jpg, frame_138240.txt
# Skipping already  existing file pair: frame_138300.jpg, frame_138300.txt
# Skipping already  existing file pair: frame_13920.jpg, frame_13920.txt
# Skipping already  existing file pair: frame_139860.jpg, frame_139860.txt
# Skipping already  existing file pair: frame_139920.jpg, frame_139920.txt
# Skipping already  existing file pair: frame_140220.jpg, frame_140220.txt
# Skipping already  existing file pair: frame_14340.jpg, frame_14340.txt
# Skipping already  existing file pair: frame_143820.jpg, frame_143820.txt
# Skipping already  existing file pair: frame_143880.jpg, frame_143880.txt
# Skipping already  existing file pair: frame_1440.jpg, frame_1440.txt
# Skipping already  existing file pair: frame_145980.jpg, frame_145980.txt
# Skipping already  existing file pair: frame_14760.jpg, frame_14760.txt
# Skipping already  existing file pair: frame_147720.jpg, frame_147720.txt
# Skipping already  existing file pair: frame_149400.jpg, frame_149400.txt
# Skipping already  existing file pair: frame_149460.jpg, frame_149460.txt
# Skipping already  existing file pair: frame_1500.jpg, frame_1500.txt
# Skipping already  existing file pair: frame_153360.jpg, frame_153360.txt
# Skipping already  existing file pair: frame_153420.jpg, frame_153420.txt
# Skipping already  existing file pair: frame_1560.jpg, frame_1560.txt
# Skipping already  existing file pair: frame_158400.jpg, frame_158400.txt
# Skipping already  existing file pair: frame_158460.jpg, frame_158460.txt
# Skipping already  existing file pair: frame_158520.jpg, frame_158520.txt
# Skipping already  existing file pair: frame_159420.jpg, frame_159420.txt
# Skipping already  existing file pair: frame_159960.jpg, frame_159960.txt
# Skipping already  existing file pair: frame_160020.jpg, frame_160020.txt
# Skipping already  existing file pair: frame_160080.jpg, frame_160080.txt
# Skipping already  existing file pair: frame_160140.jpg, frame_160140.txt
# Skipping already  existing file pair: frame_16020.jpg, frame_16020.txt
# Skipping already  existing file pair: frame_16080.jpg, frame_16080.txt
# Skipping already  existing file pair: frame_1620.jpg, frame_1620.txt
# Skipping already  existing file pair: frame_16500.jpg, frame_16500.txt
# Skipping already  existing file pair: frame_169260.jpg, frame_169260.txt
# Skipping already  existing file pair: frame_169500.jpg, frame_169500.txt
# Skipping already  existing file pair: frame_169560.jpg, frame_169560.txt
# Skipping already  existing file pair: frame_17640.jpg, frame_17640.txt
# Skipping already  existing file pair: frame_178260.jpg, frame_178260.txt
# Skipping already  existing file pair: frame_178320.jpg, frame_178320.txt
# Skipping already  existing file pair: frame_18000.jpg, frame_18000.txt
# Skipping already  existing file pair: frame_18060.jpg, frame_18060.txt
# Skipping already  existing file pair: frame_182760.jpg, frame_182760.txt
# Skipping already  existing file pair: frame_18300.jpg, frame_18300.txt
# Skipping already  existing file pair: frame_18420.jpg, frame_18420.txt
# Skipping already  existing file pair: frame_184200.jpg, frame_184200.txt
# Skipping already  existing file pair: frame_18480.jpg, frame_18480.txt
# Skipping already  existing file pair: frame_18600.jpg, frame_18600.txt
# Skipping already  existing file pair: frame_18660.jpg, frame_18660.txt
# Skipping already  existing file pair: frame_186720.jpg, frame_186720.txt
# Skipping already  existing file pair: frame_18720.jpg, frame_18720.txt
# Skipping already  existing file pair: frame_18780.jpg, frame_18780.txt
# Skipping already  existing file pair: frame_18840.jpg, frame_18840.txt
# Skipping already  existing file pair: frame_18900.jpg, frame_18900.txt
# Skipping already  existing file pair: frame_18960.jpg, frame_18960.txt
# Skipping already  existing file pair: frame_190020.jpg, frame_190020.txt
# Skipping already  existing file pair: frame_19080.jpg, frame_19080.txt
# Skipping already  existing file pair: frame_191220.jpg, frame_191220.txt
# Skipping already  existing file pair: frame_19200.jpg, frame_19200.txt
# Skipping already  existing file pair: frame_19260.jpg, frame_19260.txt
# Skipping already  existing file pair: frame_19320.jpg, frame_19320.txt
# Skipping already  existing file pair: frame_19380.jpg, frame_19380.txt
# Skipping already  existing file pair: frame_19440.jpg, frame_19440.txt
# Skipping already  existing file pair: frame_19500.jpg, frame_19500.txt
# Skipping already  existing file pair: frame_19620.jpg, frame_19620.txt
# Skipping already  existing file pair: frame_19680.jpg, frame_19680.txt
# Skipping already  existing file pair: frame_1980.jpg, frame_1980.txt
# Skipping already  existing file pair: frame_19800.jpg, frame_19800.txt
# Skipping already  existing file pair: frame_19860.jpg, frame_19860.txt
# Skipping already  existing file pair: frame_19920.jpg, frame_19920.txt
# Skipping already  existing file pair: frame_19980.jpg, frame_19980.txt
# Skipping already  existing file pair: frame_20040.jpg, frame_20040.txt
# Skipping already  existing file pair: frame_20100.jpg, frame_20100.txt
# Skipping already  existing file pair: frame_20160.jpg, frame_20160.txt
# Skipping already  existing file pair: frame_20340.jpg, frame_20340.txt
# Skipping already  existing file pair: frame_2040.jpg, frame_2040.txt
# Skipping already  existing file pair: frame_20400.jpg, frame_20400.txt
# Skipping already  existing file pair: frame_20460.jpg, frame_20460.txt
# Skipping already  existing file pair: frame_20520.jpg, frame_20520.txt
# Skipping already  existing file pair: frame_20580.jpg, frame_20580.txt
# Skipping already  existing file pair: frame_20640.jpg, frame_20640.txt
# Skipping already  existing file pair: frame_20700.jpg, frame_20700.txt
# Skipping already  existing file pair: frame_20760.jpg, frame_20760.txt
# Skipping already  existing file pair: frame_20820.jpg, frame_20820.txt
# Skipping already  existing file pair: frame_20880.jpg, frame_20880.txt
# Skipping already  existing file pair: frame_20940.jpg, frame_20940.txt
# Skipping already  existing file pair: frame_2100.jpg, frame_2100.txt
# Skipping already  existing file pair: frame_21000.jpg, frame_21000.txt
# Skipping already  existing file pair: frame_21060.jpg, frame_21060.txt
# Skipping already  existing file pair: frame_21120.jpg, frame_21120.txt
# Skipping already  existing file pair: frame_21180.jpg, frame_21180.txt
# Skipping already  existing file pair: frame_21240.jpg, frame_21240.txt
# Skipping already  existing file pair: frame_21360.jpg, frame_21360.txt
# Skipping already  existing file pair: frame_21480.jpg, frame_21480.txt
# Skipping already  existing file pair: frame_21600.jpg, frame_21600.txt
# Skipping already  existing file pair: frame_21660.jpg, frame_21660.txt
# Skipping already  existing file pair: frame_21720.jpg, frame_21720.txt
# Skipping already  existing file pair: frame_21840.jpg, frame_21840.txt
# Skipping already  existing file pair: frame_21960.jpg, frame_21960.txt
# Skipping already  existing file pair: frame_22080.jpg, frame_22080.txt
# Skipping already  existing file pair: frame_22140.jpg, frame_22140.txt
# Skipping already  existing file pair: frame_22200.jpg, frame_22200.txt
# Skipping already  existing file pair: frame_22320.jpg, frame_22320.txt
# Skipping already  existing file pair: frame_22380.jpg, frame_22380.txt
# Skipping already  existing file pair: frame_22560.jpg, frame_22560.txt
# Skipping already  existing file pair: frame_22620.jpg, frame_22620.txt
# Skipping already  existing file pair: frame_22680.jpg, frame_22680.txt
# Skipping already  existing file pair: frame_22740.jpg, frame_22740.txt
# Skipping already  existing file pair: frame_2280.jpg, frame_2280.txt
# Skipping already  existing file pair: frame_22800.jpg, frame_22800.txt
# Skipping already  existing file pair: frame_23100.jpg, frame_23100.txt
# Skipping already  existing file pair: frame_23220.jpg, frame_23220.txt
# Skipping already  existing file pair: frame_2340.jpg, frame_2340.txt
# Skipping already  existing file pair: frame_23460.jpg, frame_23460.txt
# Skipping already  existing file pair: frame_23520.jpg, frame_23520.txt
# Skipping already  existing file pair: frame_23580.jpg, frame_23580.txt
# Skipping already  existing file pair: frame_23640.jpg, frame_23640.txt
# Skipping already  existing file pair: frame_23700.jpg, frame_23700.txt
# Skipping already  existing file pair: frame_23760.jpg, frame_23760.txt
# Skipping already  existing file pair: frame_24000.jpg, frame_24000.txt
# Skipping already  existing file pair: frame_2460.jpg, frame_2460.txt
# Skipping already  existing file pair: frame_24780.jpg, frame_24780.txt
# Skipping already  existing file pair: frame_24840.jpg, frame_24840.txt
# Skipping already  existing file pair: frame_24900.jpg, frame_24900.txt
# Skipping already  existing file pair: frame_25020.jpg, frame_25020.txt
# Skipping already  existing file pair: frame_25080.jpg, frame_25080.txt
# Skipping already  existing file pair: frame_25140.jpg, frame_25140.txt
# Skipping already  existing file pair: frame_2520.jpg, frame_2520.txt
# Skipping already  existing file pair: frame_25260.jpg, frame_25260.txt
# Skipping already  existing file pair: frame_25380.jpg, frame_25380.txt
# Skipping already  existing file pair: frame_25440.jpg, frame_25440.txt
# Skipping already  existing file pair: frame_25620.jpg, frame_25620.txt
# Skipping already  existing file pair: frame_2580.jpg, frame_2580.txt
# Skipping already  existing file pair: frame_25800.jpg, frame_25800.txt
# Skipping already  existing file pair: frame_25920.jpg, frame_25920.txt
# Skipping already  existing file pair: frame_25980.jpg, frame_25980.txt
# Skipping already  existing file pair: frame_26040.jpg, frame_26040.txt
# Skipping already  existing file pair: frame_26100.jpg, frame_26100.txt
# Skipping already  existing file pair: frame_26160.jpg, frame_26160.txt
# Skipping already  existing file pair: frame_26220.jpg, frame_26220.txt
# Skipping already  existing file pair: frame_2640.jpg, frame_2640.txt
# Skipping already  existing file pair: frame_26640.jpg, frame_26640.txt
# Skipping already  existing file pair: frame_27120.jpg, frame_27120.txt
# Skipping already  existing file pair: frame_27480.jpg, frame_27480.txt
# Skipping already  existing file pair: frame_27540.jpg, frame_27540.txt
# Skipping already  existing file pair: frame_2760.jpg, frame_2760.txt
# Skipping already  existing file pair: frame_27600.jpg, frame_27600.txt
# Skipping already  existing file pair: frame_27720.jpg, frame_27720.txt
# Skipping already  existing file pair: frame_27780.jpg, frame_27780.txt
# Skipping already  existing file pair: frame_27840.jpg, frame_27840.txt
# Skipping already  existing file pair: frame_27960.jpg, frame_27960.txt
# Skipping already  existing file pair: frame_28140.jpg, frame_28140.txt
# Skipping already  existing file pair: frame_28200.jpg, frame_28200.txt
# Skipping already  existing file pair: frame_28260.jpg, frame_28260.txt
# Skipping already  existing file pair: frame_28320.jpg, frame_28320.txt
# Skipping already  existing file pair: frame_28560.jpg, frame_28560.txt
# Skipping already  existing file pair: frame_28680.jpg, frame_28680.txt
# Skipping already  existing file pair: frame_28740.jpg, frame_28740.txt
# Skipping already  existing file pair: frame_28800.jpg, frame_28800.txt
# Skipping already  existing file pair: frame_28860.jpg, frame_28860.txt
# Skipping already  existing file pair: frame_29100.jpg, frame_29100.txt
# Skipping already  existing file pair: frame_29160.jpg, frame_29160.txt
# Skipping already  existing file pair: frame_29220.jpg, frame_29220.txt
# Skipping already  existing file pair: frame_29340.jpg, frame_29340.txt
# Skipping already  existing file pair: frame_29580.jpg, frame_29580.txt
# Skipping already  existing file pair: frame_29640.jpg, frame_29640.txt
# Skipping already  existing file pair: frame_29700.jpg, frame_29700.txt
# Skipping already  existing file pair: frame_29760.jpg, frame_29760.txt
# Skipping already  existing file pair: frame_29820.jpg, frame_29820.txt
# Skipping already  existing file pair: frame_3000.jpg, frame_3000.txt
# Skipping already  existing file pair: frame_30000.jpg, frame_30000.txt
# Skipping already  existing file pair: frame_30420.jpg, frame_30420.txt
# Skipping already  existing file pair: frame_30540.jpg, frame_30540.txt
# Skipping already  existing file pair: frame_30660.jpg, frame_30660.txt
# Skipping already  existing file pair: frame_30960.jpg, frame_30960.txt
# Skipping already  existing file pair: frame_31020.jpg, frame_31020.txt
# Skipping already  existing file pair: frame_31740.jpg, frame_31740.txt
# Skipping already  existing file pair: frame_3180.jpg, frame_3180.txt
# Skipping already  existing file pair: frame_31860.jpg, frame_31860.txt
# Skipping already  existing file pair: frame_32280.jpg, frame_32280.txt
# Skipping already  existing file pair: frame_32340.jpg, frame_32340.txt
# Skipping already  existing file pair: frame_3240.jpg, frame_3240.txt
# Skipping already  existing file pair: frame_32400.jpg, frame_32400.txt
# Skipping already  existing file pair: frame_32460.jpg, frame_32460.txt
# Skipping already  existing file pair: frame_32820.jpg, frame_32820.txt
# Skipping already  existing file pair: frame_3300.jpg, frame_3300.txt
# Skipping already  existing file pair: frame_33240.jpg, frame_33240.txt
# Skipping already  existing file pair: frame_33420.jpg, frame_33420.txt
# Skipping already  existing file pair: frame_3360.jpg, frame_3360.txt
# Skipping already  existing file pair: frame_33720.jpg, frame_33720.txt
# Skipping already  existing file pair: frame_33840.jpg, frame_33840.txt
# Skipping already  existing file pair: frame_33960.jpg, frame_33960.txt
# Skipping already  existing file pair: frame_34020.jpg, frame_34020.txt
# Skipping already  existing file pair: frame_34080.jpg, frame_34080.txt
# Skipping already  existing file pair: frame_3420.jpg, frame_3420.txt
# Skipping already  existing file pair: frame_34740.jpg, frame_34740.txt
# Skipping already  existing file pair: frame_3480.jpg, frame_3480.txt
# Skipping already  existing file pair: frame_34800.jpg, frame_34800.txt
# Skipping already  existing file pair: frame_34860.jpg, frame_34860.txt
# Skipping already  existing file pair: frame_34920.jpg, frame_34920.txt
# Skipping already  existing file pair: frame_34980.jpg, frame_34980.txt
# Skipping already  existing file pair: frame_35040.jpg, frame_35040.txt
# Skipping already  existing file pair: frame_35220.jpg, frame_35220.txt
# Skipping already  existing file pair: frame_35340.jpg, frame_35340.txt
# Skipping already  existing file pair: frame_3540.jpg, frame_3540.txt
# Skipping already  existing file pair: frame_35460.jpg, frame_35460.txt
# Skipping already  existing file pair: frame_35520.jpg, frame_35520.txt
# Skipping already  existing file pair: frame_35580.jpg, frame_35580.txt
# Skipping already  existing file pair: frame_35640.jpg, frame_35640.txt
# Skipping already  existing file pair: frame_35700.jpg, frame_35700.txt
# Skipping already  existing file pair: frame_35760.jpg, frame_35760.txt
# Skipping already  existing file pair: frame_360.jpg, frame_360.txt
# Skipping already  existing file pair: frame_36120.jpg, frame_36120.txt
# Skipping already  existing file pair: frame_36180.jpg, frame_36180.txt
# Skipping already  existing file pair: frame_36240.jpg, frame_36240.txt
# Skipping already  existing file pair: frame_36480.jpg, frame_36480.txt
# Skipping already  existing file pair: frame_36540.jpg, frame_36540.txt
# Skipping already  existing file pair: frame_36600.jpg, frame_36600.txt
# Skipping already  existing file pair: frame_36660.jpg, frame_36660.txt
# Skipping already  existing file pair: frame_36720.jpg, frame_36720.txt
# Skipping already  existing file pair: frame_36840.jpg, frame_36840.txt
# Skipping already  existing file pair: frame_37080.jpg, frame_37080.txt
# Skipping already  existing file pair: frame_37380.jpg, frame_37380.txt
# Skipping already  existing file pair: frame_37500.jpg, frame_37500.txt
# Skipping already  existing file pair: frame_37560.jpg, frame_37560.txt
# Skipping already  existing file pair: frame_37620.jpg, frame_37620.txt
# Skipping already  existing file pair: frame_37740.jpg, frame_37740.txt
# Skipping already  existing file pair: frame_3780.jpg, frame_3780.txt
# Skipping already  existing file pair: frame_37800.jpg, frame_37800.txt
# Skipping already  existing file pair: frame_37860.jpg, frame_37860.txt
# Skipping already  existing file pair: frame_37920.jpg, frame_37920.txt
# Skipping already  existing file pair: frame_37980.jpg, frame_37980.txt
# Skipping already  existing file pair: frame_38280.jpg, frame_38280.txt
# Skipping already  existing file pair: frame_38340.jpg, frame_38340.txt
# Skipping already  existing file pair: frame_3840.jpg, frame_3840.txt
# Skipping already  existing file pair: frame_38460.jpg, frame_38460.txt
# Skipping already  existing file pair: frame_38520.jpg, frame_38520.txt
# Skipping already  existing file pair: frame_38580.jpg, frame_38580.txt
# Skipping already  existing file pair: frame_38640.jpg, frame_38640.txt
# Skipping already  existing file pair: frame_39060.jpg, frame_39060.txt
# Skipping already  existing file pair: frame_39120.jpg, frame_39120.txt
# Skipping already  existing file pair: frame_39180.jpg, frame_39180.txt
# Skipping already  existing file pair: frame_39420.jpg, frame_39420.txt
# Skipping already  existing file pair: frame_39480.jpg, frame_39480.txt
# Skipping already  existing file pair: frame_39540.jpg, frame_39540.txt
# Skipping already  existing file pair: frame_39720.jpg, frame_39720.txt
# Skipping already  existing file pair: frame_39780.jpg, frame_39780.txt
# Skipping already  existing file pair: frame_39840.jpg, frame_39840.txt
# Skipping already  existing file pair: frame_39960.jpg, frame_39960.txt
# Skipping already  existing file pair: frame_40080.jpg, frame_40080.txt
# Skipping already  existing file pair: frame_40200.jpg, frame_40200.txt
# Skipping already  existing file pair: frame_40260.jpg, frame_40260.txt
# Skipping already  existing file pair: frame_40620.jpg, frame_40620.txt
# Skipping already  existing file pair: frame_40680.jpg, frame_40680.txt
# Skipping already  existing file pair: frame_40740.jpg, frame_40740.txt
# Skipping already  existing file pair: frame_40920.jpg, frame_40920.txt
# Skipping already  existing file pair: frame_41280.jpg, frame_41280.txt
# Skipping already  existing file pair: frame_41340.jpg, frame_41340.txt
# Skipping already  existing file pair: frame_42060.jpg, frame_42060.txt
# Skipping already  existing file pair: frame_42180.jpg, frame_42180.txt
# Skipping already  existing file pair: frame_42240.jpg, frame_42240.txt
# Skipping already  existing file pair: frame_42360.jpg, frame_42360.txt
# Skipping already  existing file pair: frame_42420.jpg, frame_42420.txt
# Skipping already  existing file pair: frame_42600.jpg, frame_42600.txt
# Skipping already  existing file pair: frame_42660.jpg, frame_42660.txt
# Skipping already  existing file pair: frame_42720.jpg, frame_42720.txt
# Skipping already  existing file pair: frame_42900.jpg, frame_42900.txt
# Skipping already  existing file pair: frame_42960.jpg, frame_42960.txt
# Skipping already  existing file pair: frame_43020.jpg, frame_43020.txt
# Skipping already  existing file pair: frame_43080.jpg, frame_43080.txt
# Skipping already  existing file pair: frame_43140.jpg, frame_43140.txt
# Skipping already  existing file pair: frame_4320.jpg, frame_4320.txt
# Skipping already  existing file pair: frame_43200.jpg, frame_43200.txt
# Skipping already  existing file pair: frame_43260.jpg, frame_43260.txt
# Skipping already  existing file pair: frame_43440.jpg, frame_43440.txt
# Skipping already  existing file pair: frame_43500.jpg, frame_43500.txt
# Skipping already  existing file pair: frame_43740.jpg, frame_43740.txt
# Skipping already  existing file pair: frame_43800.jpg, frame_43800.txt
# Skipping already  existing file pair: frame_43920.jpg, frame_43920.txt
# Skipping already  existing file pair: frame_43980.jpg, frame_43980.txt
# Skipping already  existing file pair: frame_44100.jpg, frame_44100.txt
# Skipping already  existing file pair: frame_44160.jpg, frame_44160.txt
# Skipping already  existing file pair: frame_44220.jpg, frame_44220.txt
# Skipping already  existing file pair: frame_44280.jpg, frame_44280.txt
# Skipping already  existing file pair: frame_4440.jpg, frame_4440.txt
# Skipping already  existing file pair: frame_44400.jpg, frame_44400.txt
# Skipping already  existing file pair: frame_44520.jpg, frame_44520.txt
# Skipping already  existing file pair: frame_44580.jpg, frame_44580.txt
# Skipping already  existing file pair: frame_44760.jpg, frame_44760.txt
# Skipping already  existing file pair: frame_44820.jpg, frame_44820.txt
# Skipping already  existing file pair: frame_4500.jpg, frame_4500.txt
# Skipping already  existing file pair: frame_45060.jpg, frame_45060.txt
# Skipping already  existing file pair: frame_45180.jpg, frame_45180.txt
# Skipping already  existing file pair: frame_45300.jpg, frame_45300.txt
# Skipping already  existing file pair: frame_45360.jpg, frame_45360.txt
# Skipping already  existing file pair: frame_45540.jpg, frame_45540.txt
# Skipping already  existing file pair: frame_4560.jpg, frame_4560.txt
# Skipping already  existing file pair: frame_45660.jpg, frame_45660.txt
# Skipping already  existing file pair: frame_45720.jpg, frame_45720.txt
# Skipping already  existing file pair: frame_45780.jpg, frame_45780.txt
# Skipping already  existing file pair: frame_45840.jpg, frame_45840.txt
# Skipping already  existing file pair: frame_45900.jpg, frame_45900.txt
# Skipping already  existing file pair: frame_46020.jpg, frame_46020.txt
# Skipping already  existing file pair: frame_4620.jpg, frame_4620.txt
# Skipping already  existing file pair: frame_46200.jpg, frame_46200.txt
# Skipping already  existing file pair: frame_46320.jpg, frame_46320.txt
# Skipping already  existing file pair: frame_46380.jpg, frame_46380.txt
# Skipping already  existing file pair: frame_46440.jpg, frame_46440.txt
# Skipping already  existing file pair: frame_46500.jpg, frame_46500.txt
# Skipping already  existing file pair: frame_46560.jpg, frame_46560.txt
# Skipping already  existing file pair: frame_46740.jpg, frame_46740.txt
# Skipping already  existing file pair: frame_4680.jpg, frame_4680.txt
# Skipping already  existing file pair: frame_46860.jpg, frame_46860.txt
# Skipping already  existing file pair: frame_46920.jpg, frame_46920.txt
# Skipping already  existing file pair: frame_47040.jpg, frame_47040.txt
# Skipping already  existing file pair: frame_47220.jpg, frame_47220.txt
# Skipping already  existing file pair: frame_4740.jpg, frame_4740.txt
# Skipping already  existing file pair: frame_47460.jpg, frame_47460.txt
# Skipping already  existing file pair: frame_47580.jpg, frame_47580.txt
# Skipping already  existing file pair: frame_47640.jpg, frame_47640.txt
# Skipping already  existing file pair: frame_47700.jpg, frame_47700.txt
# Skipping already  existing file pair: frame_4800.jpg, frame_4800.txt
# Skipping already  existing file pair: frame_48540.jpg, frame_48540.txt
# Skipping already  existing file pair: frame_49800.jpg, frame_49800.txt
# Skipping already  existing file pair: frame_49860.jpg, frame_49860.txt
# Skipping already  existing file pair: frame_49920.jpg, frame_49920.txt
# Skipping already  existing file pair: frame_49980.jpg, frame_49980.txt
# Skipping already  existing file pair: frame_50280.jpg, frame_50280.txt
# Skipping already  existing file pair: frame_50340.jpg, frame_50340.txt
# Skipping already  existing file pair: frame_5040.jpg, frame_5040.txt
# Skipping already  existing file pair: frame_50400.jpg, frame_50400.txt
# Skipping already  existing file pair: frame_50700.jpg, frame_50700.txt
# Skipping already  existing file pair: frame_50760.jpg, frame_50760.txt
# Skipping already  existing file pair: frame_50820.jpg, frame_50820.txt
# Skipping already  existing file pair: frame_5100.jpg, frame_5100.txt
# Skipping already  existing file pair: frame_5160.jpg, frame_5160.txt
# Skipping already  existing file pair: frame_51660.jpg, frame_51660.txt
# Skipping already  existing file pair: frame_52380.jpg, frame_52380.txt
# Skipping already  existing file pair: frame_52500.jpg, frame_52500.txt
# Skipping already  existing file pair: frame_52560.jpg, frame_52560.txt
# Skipping already  existing file pair: frame_52980.jpg, frame_52980.txt
# Skipping already  existing file pair: frame_53040.jpg, frame_53040.txt
# Skipping already  existing file pair: frame_53580.jpg, frame_53580.txt
# Skipping already  existing file pair: frame_53880.jpg, frame_53880.txt
# Skipping already  existing file pair: frame_53940.jpg, frame_53940.txt
# Skipping already  existing file pair: frame_54000.jpg, frame_54000.txt
# Skipping already  existing file pair: frame_54060.jpg, frame_54060.txt
# Skipping already  existing file pair: frame_54180.jpg, frame_54180.txt
# Skipping already  existing file pair: frame_54240.jpg, frame_54240.txt
# Skipping already  existing file pair: frame_54360.jpg, frame_54360.txt
# Skipping already  existing file pair: frame_54420.jpg, frame_54420.txt
# Skipping already  existing file pair: frame_54540.jpg, frame_54540.txt
# Skipping already  existing file pair: frame_54600.jpg, frame_54600.txt
# Skipping already  existing file pair: frame_54780.jpg, frame_54780.txt
# Skipping already  existing file pair: frame_55020.jpg, frame_55020.txt
# Skipping already  existing file pair: frame_55260.jpg, frame_55260.txt
# Skipping already  existing file pair: frame_55500.jpg, frame_55500.txt
# Skipping already  existing file pair: frame_55560.jpg, frame_55560.txt
# Skipping already  existing file pair: frame_55680.jpg, frame_55680.txt
# Skipping already  existing file pair: frame_55740.jpg, frame_55740.txt
# Skipping already  existing file pair: frame_55800.jpg, frame_55800.txt
# Skipping already  existing file pair: frame_55920.jpg, frame_55920.txt
# Skipping already  existing file pair: frame_55980.jpg, frame_55980.txt
# Skipping already  existing file pair: frame_56040.jpg, frame_56040.txt
# Skipping already  existing file pair: frame_56160.jpg, frame_56160.txt
# Skipping already  existing file pair: frame_56280.jpg, frame_56280.txt
# Skipping already  existing file pair: frame_56340.jpg, frame_56340.txt
# Skipping already  existing file pair: frame_56400.jpg, frame_56400.txt
# Skipping already  existing file pair: frame_56460.jpg, frame_56460.txt
# Skipping already  existing file pair: frame_56580.jpg, frame_56580.txt
# Skipping already  existing file pair: frame_56760.jpg, frame_56760.txt
# Skipping already  existing file pair: frame_5700.jpg, frame_5700.txt
# Skipping already  existing file pair: frame_57000.jpg, frame_57000.txt
# Skipping already  existing file pair: frame_57060.jpg, frame_57060.txt
# Skipping already  existing file pair: frame_57240.jpg, frame_57240.txt
# Skipping already  existing file pair: frame_57300.jpg, frame_57300.txt
# Skipping already  existing file pair: frame_57420.jpg, frame_57420.txt
# Skipping already  existing file pair: frame_57480.jpg, frame_57480.txt
# Skipping already  existing file pair: frame_57540.jpg, frame_57540.txt
# Skipping already  existing file pair: frame_57600.jpg, frame_57600.txt
# Skipping already  existing file pair: frame_57660.jpg, frame_57660.txt
# Skipping already  existing file pair: frame_57780.jpg, frame_57780.txt
# Skipping already  existing file pair: frame_57900.jpg, frame_57900.txt
# Skipping already  existing file pair: frame_57960.jpg, frame_57960.txt
# Skipping already  existing file pair: frame_5820.jpg, frame_5820.txt
# Skipping already  existing file pair: frame_58200.jpg, frame_58200.txt
# Skipping already  existing file pair: frame_58260.jpg, frame_58260.txt
# Skipping already  existing file pair: frame_58380.jpg, frame_58380.txt
# Skipping already  existing file pair: frame_58440.jpg, frame_58440.txt
# Skipping already  existing file pair: frame_58560.jpg, frame_58560.txt
# Skipping already  existing file pair: frame_58620.jpg, frame_58620.txt
# Skipping already  existing file pair: frame_5880.jpg, frame_5880.txt
# Skipping already  existing file pair: frame_58860.jpg, frame_58860.txt
# Skipping already  existing file pair: frame_58980.jpg, frame_58980.txt
# Skipping already  existing file pair: frame_59040.jpg, frame_59040.txt
# Skipping already  existing file pair: frame_59100.jpg, frame_59100.txt
# Skipping already  existing file pair: frame_59220.jpg, frame_59220.txt
# Skipping already  existing file pair: frame_59280.jpg, frame_59280.txt
# Skipping already  existing file pair: frame_59460.jpg, frame_59460.txt
# Skipping already  existing file pair: frame_59520.jpg, frame_59520.txt
# Skipping already  existing file pair: frame_59580.jpg, frame_59580.txt
# Skipping already  existing file pair: frame_59640.jpg, frame_59640.txt
# Skipping already  existing file pair: frame_59700.jpg, frame_59700.txt
# Skipping already  existing file pair: frame_59880.jpg, frame_59880.txt
# Skipping already  existing file pair: frame_59940.jpg, frame_59940.txt
# Skipping already  existing file pair: frame_60780.jpg, frame_60780.txt
# Skipping already  existing file pair: frame_61020.jpg, frame_61020.txt
# Skipping already  existing file pair: frame_61080.jpg, frame_61080.txt
# Skipping already  existing file pair: frame_61320.jpg, frame_61320.txt
# Skipping already  existing file pair: frame_61380.jpg, frame_61380.txt
# Skipping already  existing file pair: frame_61500.jpg, frame_61500.txt
# Skipping already  existing file pair: frame_61620.jpg, frame_61620.txt
# Skipping already  existing file pair: frame_61680.jpg, frame_61680.txt
# Skipping already  existing file pair: frame_61740.jpg, frame_61740.txt
# Skipping already  existing file pair: frame_61800.jpg, frame_61800.txt
# Skipping already  existing file pair: frame_61860.jpg, frame_61860.txt
# Skipping already  existing file pair: frame_61920.jpg, frame_61920.txt
# Skipping already  existing file pair: frame_61980.jpg, frame_61980.txt
# Skipping already  existing file pair: frame_62040.jpg, frame_62040.txt
# Skipping already  existing file pair: frame_62100.jpg, frame_62100.txt
# Skipping already  existing file pair: frame_62220.jpg, frame_62220.txt
# Skipping already  existing file pair: frame_62280.jpg, frame_62280.txt
# Skipping already  existing file pair: frame_62340.jpg, frame_62340.txt
# Skipping already  existing file pair: frame_6240.jpg, frame_6240.txt
# Skipping already  existing file pair: frame_62460.jpg, frame_62460.txt
# Skipping already  existing file pair: frame_62520.jpg, frame_62520.txt
# Skipping already  existing file pair: frame_62640.jpg, frame_62640.txt
# Skipping already  existing file pair: frame_6300.jpg, frame_6300.txt
# Skipping already  existing file pair: frame_6360.jpg, frame_6360.txt
# Skipping already  existing file pair: frame_63660.jpg, frame_63660.txt
# Skipping already  existing file pair: frame_63720.jpg, frame_63720.txt
# Skipping already  existing file pair: frame_63840.jpg, frame_63840.txt
# Skipping already  existing file pair: frame_6420.jpg, frame_6420.txt
# Skipping already  existing file pair: frame_64920.jpg, frame_64920.txt
# Skipping already  existing file pair: frame_65400.jpg, frame_65400.txt
# Skipping already  existing file pair: frame_65760.jpg, frame_65760.txt
# Skipping already  existing file pair: frame_660.jpg, frame_660.txt
# Skipping already  existing file pair: frame_66180.jpg, frame_66180.txt
# Skipping already  existing file pair: frame_66240.jpg, frame_66240.txt
# Skipping already  existing file pair: frame_66540.jpg, frame_66540.txt
# Skipping already  existing file pair: frame_66600.jpg, frame_66600.txt
# Skipping already  existing file pair: frame_66660.jpg, frame_66660.txt
# Skipping already  existing file pair: frame_66720.jpg, frame_66720.txt
# Skipping already  existing file pair: frame_66780.jpg, frame_66780.txt
# Skipping already  existing file pair: frame_66840.jpg, frame_66840.txt
# Skipping already  existing file pair: frame_66900.jpg, frame_66900.txt
# Skipping already  existing file pair: frame_67080.jpg, frame_67080.txt
# Skipping already  existing file pair: frame_67920.jpg, frame_67920.txt
# Skipping already  existing file pair: frame_68460.jpg, frame_68460.txt
# Skipping already  existing file pair: frame_68580.jpg, frame_68580.txt
# Skipping already  existing file pair: frame_68760.jpg, frame_68760.txt
# Skipping already  existing file pair: frame_68880.jpg, frame_68880.txt
# Skipping already  existing file pair: frame_6900.jpg, frame_6900.txt
# Skipping already  existing file pair: frame_69240.jpg, frame_69240.txt
# Skipping already  existing file pair: frame_69300.jpg, frame_69300.txt
# Skipping already  existing file pair: frame_69360.jpg, frame_69360.txt
# Skipping already  existing file pair: frame_69480.jpg, frame_69480.txt
# Skipping already  existing file pair: frame_6960.jpg, frame_6960.txt
# Skipping already  existing file pair: frame_69840.jpg, frame_69840.txt
# Skipping already  existing file pair: frame_69900.jpg, frame_69900.txt
# Skipping already  existing file pair: frame_69960.jpg, frame_69960.txt
# Skipping already  existing file pair: frame_70140.jpg, frame_70140.txt
# Skipping already  existing file pair: frame_7020.jpg, frame_7020.txt
# Skipping already  existing file pair: frame_70200.jpg, frame_70200.txt
# Skipping already  existing file pair: frame_70500.jpg, frame_70500.txt
# Skipping already  existing file pair: frame_70800.jpg, frame_70800.txt
# Skipping already  existing file pair: frame_70860.jpg, frame_70860.txt
# Skipping already  existing file pair: frame_70920.jpg, frame_70920.txt
# Skipping already  existing file pair: frame_71220.jpg, frame_71220.txt
# Skipping already  existing file pair: frame_71280.jpg, frame_71280.txt
# Skipping already  existing file pair: frame_71340.jpg, frame_71340.txt
# Skipping already  existing file pair: frame_71400.jpg, frame_71400.txt
# Skipping already  existing file pair: frame_71460.jpg, frame_71460.txt
# Skipping already  existing file pair: frame_71520.jpg, frame_71520.txt
# Skipping already  existing file pair: frame_71580.jpg, frame_71580.txt
# Skipping already  existing file pair: frame_71640.jpg, frame_71640.txt
# Skipping already  existing file pair: frame_72120.jpg, frame_72120.txt
# Skipping already  existing file pair: frame_72180.jpg, frame_72180.txt
# Skipping already  existing file pair: frame_72360.jpg, frame_72360.txt
# Skipping already  existing file pair: frame_72600.jpg, frame_72600.txt
# Skipping already  existing file pair: frame_72660.jpg, frame_72660.txt
# Skipping already  existing file pair: frame_72780.jpg, frame_72780.txt
# Skipping already  existing file pair: frame_72840.jpg, frame_72840.txt
# Skipping already  existing file pair: frame_72900.jpg, frame_72900.txt
# Skipping already  existing file pair: frame_72960.jpg, frame_72960.txt
# Skipping already  existing file pair: frame_73020.jpg, frame_73020.txt
# Skipping already  existing file pair: frame_73080.jpg, frame_73080.txt
# Skipping already  existing file pair: frame_73140.jpg, frame_73140.txt
# Skipping already  existing file pair: frame_73200.jpg, frame_73200.txt
# Skipping already  existing file pair: frame_73260.jpg, frame_73260.txt
# Skipping already  existing file pair: frame_73320.jpg, frame_73320.txt
# Skipping already  existing file pair: frame_73380.jpg, frame_73380.txt
# Skipping already  existing file pair: frame_73500.jpg, frame_73500.txt
# Skipping already  existing file pair: frame_73560.jpg, frame_73560.txt
# Skipping already  existing file pair: frame_73620.jpg, frame_73620.txt
# Skipping already  existing file pair: frame_73800.jpg, frame_73800.txt
# Skipping already  existing file pair: frame_73860.jpg, frame_73860.txt
# Skipping already  existing file pair: frame_73920.jpg, frame_73920.txt
# Skipping already  existing file pair: frame_74160.jpg, frame_74160.txt
# Skipping already  existing file pair: frame_74280.jpg, frame_74280.txt
# Skipping already  existing file pair: frame_74460.jpg, frame_74460.txt
# Skipping already  existing file pair: frame_74520.jpg, frame_74520.txt
# Skipping already  existing file pair: frame_74580.jpg, frame_74580.txt
# Skipping already  existing file pair: frame_74640.jpg, frame_74640.txt
# Skipping already  existing file pair: frame_74700.jpg, frame_74700.txt
# Skipping already  existing file pair: frame_74820.jpg, frame_74820.txt
# Skipping already  existing file pair: frame_75060.jpg, frame_75060.txt
# Skipping already  existing file pair: frame_75180.jpg, frame_75180.txt
# Skipping already  existing file pair: frame_75300.jpg, frame_75300.txt
# Skipping already  existing file pair: frame_75360.jpg, frame_75360.txt
# Skipping already  existing file pair: frame_75420.jpg, frame_75420.txt
# Skipping already  existing file pair: frame_75540.jpg, frame_75540.txt
# Skipping already  existing file pair: frame_75600.jpg, frame_75600.txt
# Skipping already  existing file pair: frame_75780.jpg, frame_75780.txt
# Skipping already  existing file pair: frame_75840.jpg, frame_75840.txt
# Skipping already  existing file pair: frame_76080.jpg, frame_76080.txt
# Skipping already  existing file pair: frame_76140.jpg, frame_76140.txt
# Skipping already  existing file pair: frame_76200.jpg, frame_76200.txt
# Skipping already  existing file pair: frame_76320.jpg, frame_76320.txt
# Skipping already  existing file pair: frame_76500.jpg, frame_76500.txt
# Skipping already  existing file pair: frame_76680.jpg, frame_76680.txt
# ...
# Skipping already  existing file pair: frame_86160.jpg, frame_86160.txt
# Skipping already  existing file pair: frame_86220.jpg, frame_86220.txt
# Skipping already  existing file pair: frame_86640.jpg, frame_86640.txt
# Skipping already  existing file pair: frame_86760.jpg, frame_86760.txt
# Skipping already  existing file pair: frame_86820.jpg, frame_86820.txt
# Skipping already  existing file pair: frame_86940.jpg, frame_86940.txt
# Skipping already  existing file pair: frame_8700.jpg, frame_8700.txt
# Skipping already  existing file pair: frame_87360.jpg, frame_87360.txt
# Skipping already  existing file pair: frame_87420.jpg, frame_87420.txt
# Skipping already  existing file pair: frame_8760.jpg, frame_8760.txt
# Skipping already  existing file pair: frame_87600.jpg, frame_87600.txt
# Skipping already  existing file pair: frame_87660.jpg, frame_87660.txt
# Skipping already  existing file pair: frame_87720.jpg, frame_87720.txt
# Skipping already  existing file pair: frame_87780.jpg, frame_87780.txt
# Skipping already  existing file pair: frame_87900.jpg, frame_87900.txt
# Skipping already  existing file pair: frame_87960.jpg, frame_87960.txt
# Skipping already  existing file pair: frame_88620.jpg, frame_88620.txt
# Skipping already  existing file pair: frame_88680.jpg, frame_88680.txt
# Skipping already  existing file pair: frame_88740.jpg, frame_88740.txt
# Skipping already  existing file pair: frame_88800.jpg, frame_88800.txt
# Skipping already  existing file pair: frame_88980.jpg, frame_88980.txt
# Skipping already  existing file pair: frame_89040.jpg, frame_89040.txt
# Skipping already  existing file pair: frame_89100.jpg, frame_89100.txt
# Skipping already  existing file pair: frame_89160.jpg, frame_89160.txt
# Skipping already  existing file pair: frame_89340.jpg, frame_89340.txt
# Skipping already  existing file pair: frame_89520.jpg, frame_89520.txt
# Skipping already  existing file pair: frame_89700.jpg, frame_89700.txt
# Skipping already  existing file pair: frame_89880.jpg, frame_89880.txt
# Skipping already  existing file pair: frame_89940.jpg, frame_89940.txt
# Skipping already  existing file pair: frame_90000.jpg, frame_90000.txt
# Skipping already  existing file pair: frame_90060.jpg, frame_90060.txt
# Skipping already  existing file pair: frame_90120.jpg, frame_90120.txt
# Skipping already  existing file pair: frame_90180.jpg, frame_90180.txt
# Skipping already  existing file pair: frame_90240.jpg, frame_90240.txt
# Skipping already  existing file pair: frame_90300.jpg, frame_90300.txt
# Skipping already  existing file pair: frame_90420.jpg, frame_90420.txt
# Skipping already  existing file pair: frame_90480.jpg, frame_90480.txt
# Skipping already  existing file pair: frame_90540.jpg, frame_90540.txt
# Skipping already  existing file pair: frame_90600.jpg, frame_90600.txt
# Skipping already  existing file pair: frame_90660.jpg, frame_90660.txt
# Skipping already  existing file pair: frame_90780.jpg, frame_90780.txt
# Skipping already  existing file pair: frame_90840.jpg, frame_90840.txt
# Skipping already  existing file pair: frame_90900.jpg, frame_90900.txt
# Skipping already  existing file pair: frame_90960.jpg, frame_90960.txt
# Skipping already  existing file pair: frame_91140.jpg, frame_91140.txt
# Skipping already  existing file pair: frame_91200.jpg, frame_91200.txt
# Skipping already  existing file pair: frame_91260.jpg, frame_91260.txt
# Skipping already  existing file pair: frame_91380.jpg, frame_91380.txt
# Skipping already  existing file pair: frame_91440.jpg, frame_91440.txt
# Skipping already  existing file pair: frame_91560.jpg, frame_91560.txt
# Skipping already  existing file pair: frame_91620.jpg, frame_91620.txt
# Skipping already  existing file pair: frame_91740.jpg, frame_91740.txt
# Skipping already  existing file pair: frame_91800.jpg, frame_91800.txt
# Skipping already  existing file pair: frame_91980.jpg, frame_91980.txt
# Skipping already  existing file pair: frame_92100.jpg, frame_92100.txt
# Skipping already  existing file pair: frame_92220.jpg, frame_92220.txt
# Skipping already  existing file pair: frame_92280.jpg, frame_92280.txt
# Skipping already  existing file pair: frame_92340.jpg, frame_92340.txt
# Skipping already  existing file pair: frame_92400.jpg, frame_92400.txt
# Skipping already  existing file pair: frame_92460.jpg, frame_92460.txt
# Skipping already  existing file pair: frame_92520.jpg, frame_92520.txt
# Skipping already  existing file pair: frame_92700.jpg, frame_92700.txt
# Skipping already  existing file pair: frame_92760.jpg, frame_92760.txt
# Skipping already  existing file pair: frame_92820.jpg, frame_92820.txt
# Skipping already  existing file pair: frame_92880.jpg, frame_92880.txt
# Skipping already  existing file pair: frame_92940.jpg, frame_92940.txt
# Skipping already  existing file pair: frame_93000.jpg, frame_93000.txt
# Skipping already  existing file pair: frame_93300.jpg, frame_93300.txt
# Skipping already  existing file pair: frame_93360.jpg, frame_93360.txt
# Skipping already  existing file pair: frame_93420.jpg, frame_93420.txt
# Skipping already  existing file pair: frame_93600.jpg, frame_93600.txt
# Skipping already  existing file pair: frame_93840.jpg, frame_93840.txt
# Skipping already  existing file pair: frame_94080.jpg, frame_94080.txt
# Skipping already  existing file pair: frame_94140.jpg, frame_94140.txt
# Skipping already  existing file pair: frame_94200.jpg, frame_94200.txt
# Skipping already  existing file pair: frame_94320.jpg, frame_94320.txt
# Skipping already  existing file pair: frame_94380.jpg, frame_94380.txt
# Skipping already  existing file pair: frame_94620.jpg, frame_94620.txt
# Skipping already  existing file pair: frame_94740.jpg, frame_94740.txt
# Skipping already  existing file pair: frame_94860.jpg, frame_94860.txt
# Skipping already  existing file pair: frame_94920.jpg, frame_94920.txt
# Skipping already  existing file pair: frame_94980.jpg, frame_94980.txt
# Skipping already  existing file pair: frame_95040.jpg, frame_95040.txt
# Skipping already  existing file pair: frame_95100.jpg, frame_95100.txt
# Skipping already  existing file pair: frame_95220.jpg, frame_95220.txt
# Skipping already  existing file pair: frame_95280.jpg, frame_95280.txt
# Skipping already  existing file pair: frame_95340.jpg, frame_95340.txt
# Skipping already  existing file pair: frame_95460.jpg, frame_95460.txt
# Skipping already  existing file pair: frame_95520.jpg, frame_95520.txt
# Skipping already  existing file pair: frame_95580.jpg, frame_95580.txt
# Skipping already  existing file pair: frame_95640.jpg, frame_95640.txt
# Skipping already  existing file pair: frame_95700.jpg, frame_95700.txt
# Skipping already  existing file pair: frame_95820.jpg, frame_95820.txt
# Skipping already  existing file pair: frame_95880.jpg, frame_95880.txt
# Skipping already  existing file pair: frame_95940.jpg, frame_95940.txt
# Skipping already  existing file pair: frame_96240.jpg, frame_96240.txt
# Skipping already  existing file pair: frame_96300.jpg, frame_96300.txt
# Skipping already  existing file pair: frame_96360.jpg, frame_96360.txt
# Skipping already  existing file pair: frame_96420.jpg, frame_96420.txt
# Skipping already  existing file pair: frame_96540.jpg, frame_96540.txt
# Skipping already  existing file pair: frame_96600.jpg, frame_96600.txt
# Skipping already  existing file pair: frame_96720.jpg, frame_96720.txt
# Skipping already  existing file pair: frame_96780.jpg, frame_96780.txt
# Skipping already  existing file pair: frame_96840.jpg, frame_96840.txt
# Skipping already  existing file pair: frame_96960.jpg, frame_96960.txt
# Skipping already  existing file pair: frame_97020.jpg, frame_97020.txt
# Skipping already  existing file pair: frame_97080.jpg, frame_97080.txt
# Skipping already  existing file pair: frame_97140.jpg, frame_97140.txt
# Skipping already  existing file pair: frame_97200.jpg, frame_97200.txt
# Skipping already  existing file pair: frame_97320.jpg, frame_97320.txt
# Skipping already  existing file pair: frame_97380.jpg, frame_97380.txt
# Skipping already  existing file pair: frame_97500.jpg, frame_97500.txt
# Skipping already  existing file pair: frame_97560.jpg, frame_97560.txt
# Skipping already  existing file pair: frame_97620.jpg, frame_97620.txt
# Skipping already  existing file pair: frame_97680.jpg, frame_97680.txt
# Skipping already  existing file pair: frame_97800.jpg, frame_97800.txt
# Skipping already  existing file pair: frame_97860.jpg, frame_97860.txt
# Skipping already  existing file pair: frame_97920.jpg, frame_97920.txt
# Skipping already  existing file pair: frame_98040.jpg, frame_98040.txt
# Skipping already  existing file pair: frame_98340.jpg, frame_98340.txt
# Skipping already  existing file pair: frame_98400.jpg, frame_98400.txt
# Skipping already  existing file pair: frame_98460.jpg, frame_98460.txt
# Skipping already  existing file pair: frame_99120.jpg, frame_99120.txt
# Skipping already  existing file pair: frame_99300.jpg, frame_99300.txt
# Skipping already  existing file pair: frame_99600.jpg, frame_99600.txt
# Skipping already  existing file pair: frame_100200.jpg, frame_100200.txt
# Skipping already  existing file pair: frame_104700.jpg, frame_104700.txt
# Skipping already  existing file pair: frame_107460.jpg, frame_107460.txt
# Skipping already  existing file pair: frame_115020.jpg, frame_115020.txt
# Skipping already  existing file pair: frame_119940.jpg, frame_119940.txt
# Skipping already  existing file pair: frame_125160.jpg, frame_125160.txt
# Skipping already  existing file pair: frame_12540.jpg, frame_12540.txt
# Skipping already  existing file pair: frame_130020.jpg, frame_130020.txt
# Skipping already  existing file pair: frame_130440.jpg, frame_130440.txt
# Skipping already  existing file pair: frame_134100.jpg, frame_134100.txt
# Skipping already  existing file pair: frame_135960.jpg, frame_135960.txt
# Skipping already  existing file pair: frame_139740.jpg, frame_139740.txt
# Skipping already  existing file pair: frame_159900.jpg, frame_159900.txt
# Skipping already  existing file pair: frame_16260.jpg, frame_16260.txt
# Skipping already  existing file pair: frame_1680.jpg, frame_1680.txt
# Skipping already  existing file pair: frame_16980.jpg, frame_16980.txt
# Skipping already  existing file pair: frame_17100.jpg, frame_17100.txt
# Skipping already  existing file pair: frame_17700.jpg, frame_17700.txt
# Skipping already  existing file pair: frame_18360.jpg, frame_18360.txt
# Skipping already  existing file pair: frame_19140.jpg, frame_19140.txt
# Skipping already  existing file pair: frame_19740.jpg, frame_19740.txt
# Skipping already  existing file pair: frame_20220.jpg, frame_20220.txt
# Skipping already  existing file pair: frame_22500.jpg, frame_22500.txt
# Skipping already  existing file pair: frame_23280.jpg, frame_23280.txt
# Skipping already  existing file pair: frame_2400.jpg, frame_2400.txt
# Skipping already  existing file pair: frame_25320.jpg, frame_25320.txt
# Skipping already  existing file pair: frame_25680.jpg, frame_25680.txt
# Skipping already  existing file pair: frame_2820.jpg, frame_2820.txt
# Skipping already  existing file pair: frame_28620.jpg, frame_28620.txt
# Skipping already  existing file pair: frame_2880.jpg, frame_2880.txt
# Skipping already  existing file pair: frame_28980.jpg, frame_28980.txt
# Skipping already  existing file pair: frame_29280.jpg, frame_29280.txt
# Skipping already  existing file pair: frame_29400.jpg, frame_29400.txt
# Skipping already  existing file pair: frame_29460.jpg, frame_29460.txt
# Skipping already  existing file pair: frame_29940.jpg, frame_29940.txt
# Skipping already  existing file pair: frame_3120.jpg, frame_3120.txt
# Skipping already  existing file pair: frame_31680.jpg, frame_31680.txt
# Skipping already  existing file pair: frame_33600.jpg, frame_33600.txt
# Skipping already  existing file pair: frame_33780.jpg, frame_33780.txt
# Skipping already  existing file pair: frame_35160.jpg, frame_35160.txt
# Skipping already  existing file pair: frame_40560.jpg, frame_40560.txt
# Skipping already  existing file pair: frame_41940.jpg, frame_41940.txt
# Skipping already  existing file pair: frame_45240.jpg, frame_45240.txt
# Skipping already  existing file pair: frame_46620.jpg, frame_46620.txt
# Skipping already  existing file pair: frame_47160.jpg, frame_47160.txt
# Skipping already  existing file pair: frame_47520.jpg, frame_47520.txt
# Skipping already  existing file pair: frame_49020.jpg, frame_49020.txt
# Skipping already  existing file pair: frame_49080.jpg, frame_49080.txt
# Skipping already  existing file pair: frame_53820.jpg, frame_53820.txt
# Skipping already  existing file pair: frame_54120.jpg, frame_54120.txt
# Skipping already  existing file pair: frame_54300.jpg, frame_54300.txt
# Skipping already  existing file pair: frame_5580.jpg, frame_5580.txt
# Skipping already  existing file pair: frame_56520.jpg, frame_56520.txt
# Skipping already  existing file pair: frame_56640.jpg, frame_56640.txt
# Skipping already  existing file pair: frame_57720.jpg, frame_57720.txt
# Skipping already  existing file pair: frame_58020.jpg, frame_58020.txt
# Skipping already  existing file pair: frame_58800.jpg, frame_58800.txt
# Skipping already  existing file pair: frame_60000.jpg, frame_60000.txt
# Skipping already  existing file pair: frame_6120.jpg, frame_6120.txt
# Skipping already  existing file pair: frame_62400.jpg, frame_62400.txt
# Skipping already  existing file pair: frame_62700.jpg, frame_62700.txt
# Skipping already  existing file pair: frame_65580.jpg, frame_65580.txt
# Skipping already  existing file pair: frame_66300.jpg, frame_66300.txt
# Skipping already  existing file pair: frame_67860.jpg, frame_67860.txt
# Skipping already  existing file pair: frame_68160.jpg, frame_68160.txt
# Skipping already  existing file pair: frame_68520.jpg, frame_68520.txt
# Skipping already  existing file pair: frame_69420.jpg, frame_69420.txt
# Skipping already  existing file pair: frame_72240.jpg, frame_72240.txt
# Skipping already  existing file pair: frame_72720.jpg, frame_72720.txt
# Skipping already  existing file pair: frame_74100.jpg, frame_74100.txt
# Skipping already  existing file pair: frame_74220.jpg, frame_74220.txt
# Skipping already  existing file pair: frame_74340.jpg, frame_74340.txt
# Skipping already  existing file pair: frame_74760.jpg, frame_74760.txt
# Skipping already  existing file pair: frame_75120.jpg, frame_75120.txt
# Skipping already  existing file pair: frame_76920.jpg, frame_76920.txt
# Skipping already  existing file pair: frame_77580.jpg, frame_77580.txt
# Skipping already  existing file pair: frame_78240.jpg, frame_78240.txt
# Skipping already  existing file pair: frame_78960.jpg, frame_78960.txt
# Skipping already  existing file pair: frame_79320.jpg, frame_79320.txt
# Skipping already  existing file pair: frame_79740.jpg, frame_79740.txt
# Skipping already  existing file pair: frame_7980.jpg, frame_7980.txt
# Skipping already  existing file pair: frame_81360.jpg, frame_81360.txt
# Skipping already  existing file pair: frame_81780.jpg, frame_81780.txt
# Skipping already  existing file pair: frame_82080.jpg, frame_82080.txt
# Skipping already  existing file pair: frame_82620.jpg, frame_82620.txt
# Skipping already  existing file pair: frame_83760.jpg, frame_83760.txt
# Skipping already  existing file pair: frame_85800.jpg, frame_85800.txt
# Skipping already  existing file pair: frame_86880.jpg, frame_86880.txt
# Skipping already  existing file pair: frame_89460.jpg, frame_89460.txt
# Skipping already  existing file pair: frame_90720.jpg, frame_90720.txt
# Skipping already  existing file pair: frame_91020.jpg, frame_91020.txt
# Skipping already  existing file pair: frame_91080.jpg, frame_91080.txt
# Skipping already  existing file pair: frame_91680.jpg, frame_91680.txt
# Skipping already  existing file pair: frame_91860.jpg, frame_91860.txt
# Skipping already  existing file pair: frame_92040.jpg, frame_92040.txt
# Skipping already  existing file pair: frame_92160.jpg, frame_92160.txt
# Skipping already  existing file pair: frame_92580.jpg, frame_92580.txt
# Skipping already  existing file pair: frame_96180.jpg, frame_96180.txt
# Skipping already  existing file pair: frame_98280.jpg, frame_98280.txt
# Skipping already  existing file pair: frame_99660.jpg, frame_99660.txt
