# %%
import os
import numpy as np
import cv2
import random
import matplotlib.pyplot as plt

# %%
def cutmix(image1, image2, bbox1, bbox2, alpha=0.2):
    height, width, _ = image1.shape

    # Generate random bounding box
    cut_rat = np.random.rand()
    cut_w = int(width * cut_rat)
    cut_h = int(height * cut_rat)

    # Generate random center for the cut area
    cut_x = np.random.randint(width)
    cut_y = np.random.randint(height)

    # Determine the bounding box coordinates
    x1 = np.clip(cut_x - cut_w // 2, 0, width)
    y1 = np.clip(cut_y - cut_h // 2, 0, height)
    x2 = np.clip(cut_x + cut_w // 2, 0, width)
    y2 = np.clip(cut_y + cut_h // 2, 0, height)

    mixed_image = image1.copy()
    mixed_image[y1:y2, x1:x2, :]= image2[y1:y2, x1:x2, :]

    bbox1 = np.array(bbox1)
    bbox2 = np.array(bbox2)
    bbox2[:, [1, 3]] = bbox2[:, [1, 3]] * (cut_w / width) + x1 / width
    bbox2[:, [2, 4]] = bbox2[:, [2, 4]] * (cut_h / height) + y1 / height
    mixed_bboxes = np.vstack((bbox1, bbox2))

    return mixed_image, mixed_bboxes

# %%
def read_bboxes(label_path):
    with open(label_path, 'r') as f:
        bboxes = [line.strip().split() for line in f.readlines()]
    
    return [[int(bbox[0])] + [float(x) for x in bbox[1:]] for bbox in bboxes]

# %%
def save_cutmix_images_and_labels(image_dir, label_dir, output_image_dir, output_label_dir, alpha=0.2):
    image_files = [f for f in os.listdir(image_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    os.makedirs(output_image_dir, exist_ok=True)
    os.makedirs(output_label_dir, exist_ok=True)
    
    for img_file in image_files:
        img_path = os.path.join(image_dir, img_file)
        label_path = os.path.join(label_dir, img_file.rsplit('.', 1)[0] + '.txt')
        image1 = cv2.imread(img_path)
        image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
        bbox1 = read_bboxes(label_path)

        # Randomly select another image and label for cutmix
        img_file2 = random.choice(image_files)
        while img_file2 == img_file:
            img_file2 = random.choice(image_files)

        img_path2 = os.path.join(image_dir, img_file2)
        label_path2 = os.path.join(label_dir, img_file2.rsplit('.', 1)[0] + '.txt')
        image2 = cv2.imread(img_path2)
        image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)
        bbox2 = read_bboxes(label_path2)

        mixed_image, mixed_bboxes = cutmix(image1, image2, bbox1, bbox2, alpha)

        mixed_image_bgr = cv2.cvtColor(mixed_image, cv2.COLOR_RGB2BGR)
        cv2.imwrite(os.path.join(output_image_dir, img_file), mixed_image_bgr)

        with open(os.path.join(output_label_dir, img_file.rsplit('.', 1)[0] + '.txt'), 'w') as f:
            for bbox in mixed_bboxes:
                f.write(f"{int(bbox[0])} {' '.join(map(str, bbox[1:]))}\n")
        print(f"Applied cutmix and saved: {img_file}")

# %%
input_path = 'my_data'
output_path = 'test_cutmix_1'
save_cutmix_images_and_labels(f'{input_path}/images/train', f'{input_path}/labels/train', f'{output_path}/images/train', f'{output_path}/labels/train', alpha=0.2)
# Out:
# Applied cutmix and saved: frame_100200.jpg
# Applied cutmix and saved: frame_101280.jpg
# Applied cutmix and saved: frame_101460.jpg
# Applied cutmix and saved: frame_101520.jpg
# Applied cutmix and saved: frame_101820.jpg
# Applied cutmix and saved: frame_101880.jpg
# Applied cutmix and saved: frame_101940.jpg
# Applied cutmix and saved: frame_1020.jpg
# Applied cutmix and saved: frame_102060.jpg
# Applied cutmix and saved: frame_102180.jpg
# Applied cutmix and saved: frame_102420.jpg
# Applied cutmix and saved: frame_102480.jpg
# Applied cutmix and saved: frame_103500.jpg
# Applied cutmix and saved: frame_103680.jpg
# Applied cutmix and saved: frame_103740.jpg
# Applied cutmix and saved: frame_104580.jpg
# Applied cutmix and saved: frame_104640.jpg
# Applied cutmix and saved: frame_104700.jpg
# Applied cutmix and saved: frame_105120.jpg
# Applied cutmix and saved: frame_105180.jpg
# Applied cutmix and saved: frame_106320.jpg
# Applied cutmix and saved: frame_106800.jpg
# Applied cutmix and saved: frame_106980.jpg
# Applied cutmix and saved: frame_107460.jpg
# Applied cutmix and saved: frame_107520.jpg
# Applied cutmix and saved: frame_107640.jpg
# Applied cutmix and saved: frame_107820.jpg
# Applied cutmix and saved: frame_107880.jpg
# Applied cutmix and saved: frame_109080.jpg
# Applied cutmix and saved: frame_109140.jpg
# Applied cutmix and saved: frame_109200.jpg
# Applied cutmix and saved: frame_109260.jpg
# Applied cutmix and saved: frame_109740.jpg
# Applied cutmix and saved: frame_109800.jpg
# Applied cutmix and saved: frame_109920.jpg
# Applied cutmix and saved: frame_109980.jpg
# Applied cutmix and saved: frame_110040.jpg
# Applied cutmix and saved: frame_11100.jpg
# Applied cutmix and saved: frame_11160.jpg
# Applied cutmix and saved: frame_112140.jpg
# Applied cutmix and saved: frame_112920.jpg
# Applied cutmix and saved: frame_113220.jpg
# Applied cutmix and saved: frame_113280.jpg
# Applied cutmix and saved: frame_113400.jpg
# Applied cutmix and saved: frame_114900.jpg
# Applied cutmix and saved: frame_114960.jpg
# Applied cutmix and saved: frame_115020.jpg
# Applied cutmix and saved: frame_115080.jpg
# Applied cutmix and saved: frame_115140.jpg
# Applied cutmix and saved: frame_115200.jpg
# Applied cutmix and saved: frame_115260.jpg
# Applied cutmix and saved: frame_115380.jpg
# Applied cutmix and saved: frame_115440.jpg
# Applied cutmix and saved: frame_115500.jpg
# Applied cutmix and saved: frame_115680.jpg
# Applied cutmix and saved: frame_115740.jpg
# Applied cutmix and saved: frame_11580.jpg
# Applied cutmix and saved: frame_115800.jpg
# Applied cutmix and saved: frame_115860.jpg
# Applied cutmix and saved: frame_11640.jpg
# Applied cutmix and saved: frame_117060.jpg
# Applied cutmix and saved: frame_117120.jpg
# Applied cutmix and saved: frame_117180.jpg
# Applied cutmix and saved: frame_11760.jpg
# Applied cutmix and saved: frame_117600.jpg
# Applied cutmix and saved: frame_117840.jpg
# Applied cutmix and saved: frame_117900.jpg
# Applied cutmix and saved: frame_117960.jpg
# Applied cutmix and saved: frame_118020.jpg
# Applied cutmix and saved: frame_118080.jpg
# Applied cutmix and saved: frame_118140.jpg
# Applied cutmix and saved: frame_120.jpg
# Applied cutmix and saved: frame_1200.jpg
# Applied cutmix and saved: frame_120000.jpg
# Applied cutmix and saved: frame_120060.jpg
# Applied cutmix and saved: frame_120120.jpg
# Applied cutmix and saved: frame_120180.jpg
# Applied cutmix and saved: frame_121020.jpg
# Applied cutmix and saved: frame_121080.jpg
# Applied cutmix and saved: frame_121140.jpg
# Applied cutmix and saved: frame_121260.jpg
# Applied cutmix and saved: frame_121380.jpg
# Applied cutmix and saved: frame_121440.jpg
# Applied cutmix and saved: frame_121680.jpg
# Applied cutmix and saved: frame_122100.jpg
# Applied cutmix and saved: frame_122280.jpg
# Applied cutmix and saved: frame_122460.jpg
# Applied cutmix and saved: frame_122520.jpg
# Applied cutmix and saved: frame_122580.jpg
# Applied cutmix and saved: frame_122640.jpg
# Applied cutmix and saved: frame_122700.jpg
# Applied cutmix and saved: frame_122760.jpg
# Applied cutmix and saved: frame_122820.jpg
# Applied cutmix and saved: frame_122880.jpg
# Applied cutmix and saved: frame_123000.jpg
# Applied cutmix and saved: frame_123060.jpg
# Applied cutmix and saved: frame_123120.jpg
# Applied cutmix and saved: frame_123180.jpg
# Applied cutmix and saved: frame_123240.jpg
# Applied cutmix and saved: frame_123300.jpg
# Applied cutmix and saved: frame_123360.jpg
# Applied cutmix and saved: frame_123420.jpg
# Applied cutmix and saved: frame_12360.jpg
# Applied cutmix and saved: frame_123600.jpg
# Applied cutmix and saved: frame_123660.jpg
# Applied cutmix and saved: frame_12420.jpg
# Applied cutmix and saved: frame_124560.jpg
# Applied cutmix and saved: frame_124800.jpg
# Applied cutmix and saved: frame_124860.jpg
# Applied cutmix and saved: frame_124920.jpg
# Applied cutmix and saved: frame_124980.jpg
# Applied cutmix and saved: frame_125040.jpg
# Applied cutmix and saved: frame_125160.jpg
# Applied cutmix and saved: frame_125220.jpg
# Applied cutmix and saved: frame_125280.jpg
# Applied cutmix and saved: frame_125340.jpg
# Applied cutmix and saved: frame_12540.jpg
# Applied cutmix and saved: frame_125400.jpg
# Applied cutmix and saved: frame_125460.jpg
# Applied cutmix and saved: frame_125880.jpg
# Applied cutmix and saved: frame_1260.jpg
# Applied cutmix and saved: frame_12600.jpg
# Applied cutmix and saved: frame_126420.jpg
# Applied cutmix and saved: frame_126480.jpg
# Applied cutmix and saved: frame_12660.jpg
# Applied cutmix and saved: frame_127080.jpg
# Applied cutmix and saved: frame_127440.jpg
# Applied cutmix and saved: frame_12780.jpg
# Applied cutmix and saved: frame_12840.jpg
# Applied cutmix and saved: frame_130020.jpg
# Applied cutmix and saved: frame_13020.jpg
# Applied cutmix and saved: frame_130260.jpg
# Applied cutmix and saved: frame_130320.jpg
# Applied cutmix and saved: frame_130380.jpg
# Applied cutmix and saved: frame_130440.jpg
# Applied cutmix and saved: frame_13080.jpg
# Applied cutmix and saved: frame_13140.jpg
# Applied cutmix and saved: frame_1320.jpg
# Applied cutmix and saved: frame_13200.jpg
# Applied cutmix and saved: frame_132120.jpg
# Applied cutmix and saved: frame_132180.jpg
# Applied cutmix and saved: frame_132720.jpg
# Applied cutmix and saved: frame_133920.jpg
# Applied cutmix and saved: frame_133980.jpg
# Applied cutmix and saved: frame_134100.jpg
# Applied cutmix and saved: frame_134160.jpg
# Applied cutmix and saved: frame_134940.jpg
# Applied cutmix and saved: frame_135600.jpg
# Applied cutmix and saved: frame_135660.jpg
